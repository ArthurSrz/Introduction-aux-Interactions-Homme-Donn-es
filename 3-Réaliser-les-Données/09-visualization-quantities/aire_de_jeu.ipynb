# %% [markdown]
# # A propos de noms d'oiseaux

# %% [markdown]
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
birds = pd.read_csv('data/birds.csv')
birds.head()
# Out:
#                            Name          ScientificName  \
# 0  Black-bellied whistling-duck  Dendrocygna autumnalis
# 1        Fulvous whistling-duck     Dendrocygna bicolor
# 2                    Snow goose      Anser caerulescens
# 3                  Ross's goose            Anser rossii
# 4   Greater white-fronted goose         Anser albifrons
#
#                 Category         Order    Family        Genus  \
# 0  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 1  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 2  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 3  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 4  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
#
#   ConservationStatus  MinLength  MaxLength  MinBodyMass  MaxBodyMass  \
# 0                 LC       47.0       56.0        652.0       1020.0
# 1                 LC       45.0       53.0        712.0       1050.0
# ...

# %% [markdown]
# ...

# %%
plt.title('Envergure en Centimètres')
plt.ylabel('Envergure (cm)')
plt.xlabel('Oiseaux')
wingspan = birds.MaxWingspan 
wingspan.plot()
# Out:
# <Axes: title={'center': 'Envergure en Centimètres'}, xlabel='Oiseaux', ylabel='Envergure (cm)'>

# %% [markdown]
# ...

# %%
plt.title('Envergure en centimètres')
plt.ylabel('Envergure (cm)')
plt.xlabel('Oiseaux')
plt.xticks(rotation=90)
x = birds['Name'] 
y = birds['MaxWingspan']

plt.plot(x, y)

plt.show()

# %% [markdown]
# ...

# %%
plt.title('Envergure en centimètres')
plt.ylabel('Envergure (cm)')
plt.tick_params(axis='both',which='both',labelbottom=False,bottom=False)

for i in range(len(birds)):
    x = birds['Name'][i]
    y = birds['MaxWingspan'][i]
    plt.plot(x, y, 'bo')
    if birds['MaxWingspan'][i] > 500:
        plt.text(x, y * (1 - 0.15), birds['Name'][i], fontsize=12)
    
plt.show()

# %% [markdown]
# ...

# %%
plt.title('Envergure en Centimètres')
plt.ylabel('Envergure (cm)')
plt.xlabel('Oiseaux')
plt.tick_params(axis='both',which='both',labelbottom=False,bottom=False)
for i in range(len(birds)):
    x = birds['Name'][i]
    y = birds['MaxWingspan'][i]
    if birds['Name'][i] not in ['Bald eagle', 'Prairie falcon']:
        plt.plot(x, y, 'bo')
plt.show()

# %% [markdown]
# ...

# %%
birds.plot(x='Category',
        kind='bar',
        stacked=True,
        title='Oiseaux du Minnesota')
# Out:
# <Axes: title={'center': 'Oiseaux du Minnesota'}, xlabel='Category'>

# %% [markdown]
# Show the count of birds within categories, and show the labels horizontally so we can read the category names

# %%
category_count = birds.value_counts(birds['Category'].values, sort=True)
plt.rcParams['figure.figsize'] = [6, 12]
category_count.plot.barh()

# %% [markdown]
# Show the categories with their maxlength displayed per category

# %%
maxlength = birds['MaxLength']
plt.barh(y=birds['Category'], width=maxlength)
plt.rcParams['figure.figsize'] = [6, 12]
plt.show()

# %% [markdown]
# Superimpose the birds minimum and maximum lengths per category

# %%
minLength = birds['MinLength']
maxLength = birds['MaxLength']
category = birds['Category']

plt.barh(category, maxLength)
plt.barh(category, minLength)

plt.show()
